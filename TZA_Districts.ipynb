# %%
import pandas as pd  
import geopandas as gpd
import fiona
import shapely
import pyogrio
import matplotlib.pyplot as plt

# Define the districts that you want to change the color fill of 
highlight_districts = ["Tarime", "Bunda"]

# Load districts map dataset, which is in the same directory that you are working from
districts = gpd.read_file("Maps/TZAmap_districts.shp")  

# List of districts to keep out of the list that is already in the data set 
selected_districts = ["Bunda", "Butiam", "Musoma", "Nyakonga", "Rorya", "Serengeti", "Tarime", "Musoma Urban"]

# Filter the GeoDataFrame to keep only the selected districts
# This will iterate thought the dataset and only return the selected districts
filtered_districts = districts[districts["shapeName"].isin(selected_districts)]


# Filter the districts that you want to change the fill of 
districts_highlight = districts[districts["shapeName"].isin(highlight_districts)] 

# Create a figure and axis for a single plot
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the filtered districts
filtered_districts.plot(ax=ax, edgecolor="grey", linewidth=0.8, color="white")

# Plot only selected districts with color
districts_highlight.plot(ax=ax, edgecolor="#747474", linewidth=0.3, color="lightblue", alpha=0.4)

# Label each district by plotting the district name at the centroid
for idx, row in filtered_districts.iterrows():  # Iterate through the rows of the GeoDataFrame
    # Get the centroid of each district
    centroid = row.geometry.centroid
    # Add the district name at the centroid's coordinates
    ax.text(centroid.x, centroid.y, row["shapeName"], fontsize=8, ha="center", color="black")  # Add the label

#If any of the districts dont show up run this code so you can find the one you are looking for
#print(districts["district_name"].unique())

# Remove the axis
plt.axis("off")

# Label graph
plt.title("Districts in Mara")

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 50
#      42     ax.text(centroid.x, centroid.y, row["shapeName"], fontsize=8, ha="center", color="black")  # Add the label
#      46 #If any of the districts dont show up run this code so you can find the one you are looking for
#      47 #print(wards["district_name"].unique())
#      48
#      49 # to see the dataset you are working with
# ---> 50 print(wards.head())
#      52 # Remove the axis
#      53 plt.axis("off")
#
# NameError: name 'wards' is not defined

# %%
print(districts["shapeName"].unique())
# Out:
# ['Arusha' 'Arusha Urban' 'Karatu' 'Longido' 'Meru' 'Monduli' 'Ngorongoro'
#  'Ilala' 'Kinondoni' 'Temeke' 'Bahi' 'Chamwino' 'Chemba' 'Dodoma Urban'
#  'Kondoa' 'Kongwa' 'Mpwapwa' 'Bukombe' 'Chato' 'Geita' 'Mbogwe'
#  "Nyang'hwale" 'Iringa' 'Iringa Urban' 'Kilolo'
#  'Mafinga Township Authority' 'Mufindi' 'Biharamulo' 'Bukoba'
#  'Bukoba Urban' 'Karagwe' 'Kyerwa' 'Missenyi' 'Muleba' 'Ngara' 'Micheweni'
#  'Wete' 'Kaskazini A' 'Kaskazini B' 'Mlele' 'Mpanda' 'Mpanda Urban'
#  'Buhigwe' 'Kakonko' 'Kasulu' 'Kasulu Township Authority' 'Kibondo'
#  'Kigoma' 'Kigoma  Urban' 'Uvinza' 'Hai' 'Moshi' 'Moshi Urban' 'Mwanga'
#  'Rombo' 'Same' 'Siha' 'Chake Chake' 'Mkoani' 'Kati' 'Kusini' 'Kilwa'
#  'Lindi' 'Lindi Urban' 'Liwale' 'Nachingwea' 'Ruangwa' 'Babati'
#  'Babati UrbanBabati Urban' 'Hanang' 'Kiteto' 'Mbulu' 'Simanjiro' 'Bunda'
#  'Butiam' 'Musoma' 'Musoma Urban' 'Rorya' 'Serengeti' 'Tarime' 'Chunya'
#  'Kyela' 'Mbarali' 'Mbeya' 'Mbeya Urban' 'Rungwe' 'Magharibi' 'Mjini'
#  'Gairo' 'Kilombero' 'Kilosa' 'Morogoro' 'Morogoro Urban' 'Mvomero'
#  'Ulanga' 'Masasi' 'Masasi  Township Authority' 'Mtwara' 'Mtwara Urban'
#  'Nanyumbu' 'Newala' 'Tandahimba' 'Ilemela' 'Kwimba' 'Magu' 'Misungwi'
#  'Nyamagana' 'Sengerema' 'Ukerewe' 'Ludewa' 'Makambako Township Authority'
#  'Makete' 'Njombe' 'Njombe Urban' "Wanging'ombe" 'Bagamoyo' 'Kibaha'
#  'Kibaha Urban' 'Kisarawe' 'Mafia' 'Mkuranga' 'Rufiji' 'Kalambo' 'Nkasi'
#  'Sumbawanga' 'Sumbawanga Urban' 'Mbinga' 'Namtumbo' 'Nyasa' 'Songea'
#  'Songea Urban' 'Tunduru' 'Kahama' 'Kahama Township Authority' 'Kishapu'
#  'Shinyanga' 'Shinyanga Urban' 'Bariadi' 'Busega' 'Itilima' 'Maswa'
#  'Meatu' 'Ikungi' 'Iramba' 'Manyoni' 'Mkalama' 'Singida' 'Singida Urban'
#  'Ileje' 'Mbozi' 'Momba' 'Songwe' 'Tunduma' 'Igunga' 'Kaliua' 'Nzega'
#  'Sikonge' 'Tabora Urban' 'Urambo' 'Uyui' 'Handeni' 'Handeni Mji'
#  'Kilindi' 'Korogwe' 'Korogwe Township Authority' 'Lushoto' 'Mkinga'
#  'Muheza' 'Pangani' 'Tanga Urban']
